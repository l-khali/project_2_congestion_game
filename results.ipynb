# %%
import functions

# %% [markdown]
# ### Equilibria for atomic 10 player game

# %%
functions.congestion_equilibrium()
# Out:
# Number of equilibria found: 2
# [(Counter({'Path 1': 2, 'Path 2': 2, 'Path 3': 1}),
#   Counter({'Path 1': 0, 'Path 2': 0, 'Path 3': 5})),
#  (Counter({'Path 1': 1, 'Path 2': 3, 'Path 3': 1}),
#   Counter({'Path 1': 0, 'Path 2': 0, 'Path 3': 5}))]

# %%
### Equilibria for splitting flow approximation 1000 player game

# %%
functions.congestion_equilibrium(N=1000, nsim=10000)
# Out:
# Number of equilibria found: 9961
# [(Counter({'Outlet 1': 152, 'Outlet 2': 177, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 177, 'Library Cafe': 146})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 166, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 162, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 154, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 163, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 152, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 180, 'Library Cafe': 154})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 160, 'Library Cafe': 191}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 180, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 168, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 161, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 160, 'Library Cafe': 179}),
# ...
