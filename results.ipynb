# %%
import functions

# %% [markdown]
# ### Equilibria for atomic 10 player game

# %%
functions.congestion_equilibrium()
# Out:
# Number of equilibria found: 2
# Min average cost: 6.4
# Max average cost: 6.6
# [(Counter({'Outlet 1': 1, 'Outlet 2': 3, 'Library Cafe': 1}),
#   Counter({'Outlet 1': 0, 'Outlet 2': 0, 'Library Cafe': 5})),
#  (Counter({'Outlet 1': 2, 'Outlet 2': 2, 'Library Cafe': 1}),
#   Counter({'Outlet 1': 0, 'Outlet 2': 0, 'Library Cafe': 5}))]

# %%
### Equilibria for splitting flow approximation 1000 player game

# %%
functions.congestion_equilibrium(N=1000, nsim=10000)
# Out:
# Number of equilibria found: 9959
# Min average cost: 803.987
# Max average cost: 922.253
# [(Counter({'Outlet 1': 180, 'Outlet 2': 158, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 166, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 160, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 172, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 182, 'Outlet 2': 145, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 134, 'Outlet 2': 166, 'Library Cafe': 200})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 176, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 152, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 164, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 135, 'Outlet 2': 188, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 159, 'Library Cafe': 188}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 167, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 168, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 151, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 170, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 164, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 150, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 183, 'Library Cafe': 154})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 143, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 178, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 154, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 175, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 161, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 154, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 173, 'Library Cafe': 153}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 167, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 146, 'Outlet 2': 160, 'Library Cafe': 194})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 168, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 152, 'Library Cafe': 188})),
#  (Counter({'Outlet 1': 143, 'Outlet 2': 179, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 168, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 180, 'Outlet 2': 158, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 155, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 161, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 163, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 165, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 149, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 140, 'Outlet 2': 180, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 148, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 154, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 160, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 159, 'Library Cafe': 191}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 171, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 183, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 174, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 160, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 174, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 153, 'Library Cafe': 190}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 179, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 184, 'Outlet 2': 167, 'Library Cafe': 149}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 161, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 161, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 173, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 169, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 149, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 169, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 162, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 194, 'Outlet 2': 151, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 158, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 166, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 176, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 183, 'Outlet 2': 162, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 184, 'Outlet 2': 160, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 168, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 163, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 164, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 171, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 152, 'Outlet 2': 169, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 196, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 164, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 180, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 159, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 173, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 158, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 185, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 173, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 171, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 185, 'Outlet 2': 147, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 165, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 165, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 171, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 172, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 162, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 178, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 176, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 144, 'Outlet 2': 163, 'Library Cafe': 193}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 157, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 192, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 168, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 165, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 161, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 163, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 136, 'Library Cafe': 189})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 170, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 160, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 169, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 162, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 159, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 163, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 171, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 159, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 166, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 180, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 152, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 159, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 170, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 185, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 162, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 168, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 172, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 164, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 162, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 180, 'Outlet 2': 153, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 177, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 147, 'Library Cafe': 193}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 186, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 158, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 176, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 182, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 140, 'Library Cafe': 192})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 169, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 192, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 176, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 173, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 152, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 184, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 144, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 162, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 166, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 148, 'Outlet 2': 171, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 151, 'Outlet 2': 188, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 153, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 162, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 161, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 157, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 162, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 155, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 166, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 172, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 167, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 170, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 166, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 180, 'Outlet 2': 166, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 183, 'Outlet 2': 160, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 169, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 145, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 140, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 173, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 161, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 160, 'Library Cafe': 188})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 162, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 182, 'Outlet 2': 153, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 183, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 182, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 159, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 150, 'Library Cafe': 193})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 158, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 155, 'Library Cafe': 189})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 169, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 165, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 171, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 187, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 166, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 165, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 139, 'Outlet 2': 182, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 167, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 154, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 174, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 174, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 141, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 169, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 170, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 151, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 189, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 164, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 178, 'Outlet 2': 155, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 185, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 146, 'Outlet 2': 172, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 180, 'Outlet 2': 170, 'Library Cafe': 150}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 173, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 155, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 163, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 156, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 148, 'Outlet 2': 176, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 171, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 173, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 162, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 166, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 156, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 183, 'Outlet 2': 167, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 181, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 166, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 168, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 163, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 151, 'Outlet 2': 172, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 169, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 170, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 153, 'Library Cafe': 193})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 153, 'Library Cafe': 191}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 177, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 154, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 144, 'Library Cafe': 188})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 164, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 164, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 168, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 156, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 149, 'Outlet 2': 174, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 165, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 172, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 184, 'Library Cafe': 145}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 172, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 185, 'Outlet 2': 168, 'Library Cafe': 147}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 150, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 148, 'Outlet 2': 183, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 151, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 169, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 173, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 183, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 168, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 184, 'Outlet 2': 149, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 163, 'Library Cafe': 185})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 180, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 191, 'Outlet 2': 159, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 151, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 145, 'Library Cafe': 194})),
#  (Counter({'Outlet 1': 146, 'Outlet 2': 182, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 163, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 167, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 158, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 182, 'Outlet 2': 152, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 167, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 160, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 166, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 157, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 163, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 187, 'Outlet 2': 152, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 182, 'Library Cafe': 143})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 167, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 172, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 173, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 156, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 152, 'Outlet 2': 173, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 184, 'Outlet 2': 150, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 152, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 179, 'Outlet 2': 160, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 168, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 146, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 172, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 141, 'Outlet 2': 183, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 153, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 167, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 150, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 149, 'Outlet 2': 175, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 167, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 167, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 161, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 170, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 173, 'Library Cafe': 154})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 171, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 183, 'Outlet 2': 147, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 145, 'Outlet 2': 181, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 159, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 153, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 170, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 162, 'Library Cafe': 188}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 162, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 144, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 157, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 163, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 181, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 144, 'Outlet 2': 180, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 177, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 167, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 181, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 174, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 156, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 193, 'Outlet 2': 164, 'Library Cafe': 143})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 169, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 154, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 166, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 160, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 171, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 165, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 142, 'Outlet 2': 180, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 169, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 168, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 180, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 169, 'Library Cafe': 150}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 164, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 143, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 156, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 162, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 158, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 178, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 183, 'Library Cafe': 153})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 179, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 164, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 155, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 161, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 164, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 177, 'Library Cafe': 158})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 169, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 170, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 174, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 185, 'Outlet 2': 167, 'Library Cafe': 148})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 166, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 164, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 153, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 170, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 170, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 167, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 162, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 178, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 179, 'Library Cafe': 152}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 138, 'Library Cafe': 196})),
#  (Counter({'Outlet 1': 148, 'Outlet 2': 168, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 166, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 168, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 194, 'Outlet 2': 159, 'Library Cafe': 147})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 178, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 164, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 168, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 168, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 164, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 150, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 157, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 164, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 156, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 158, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 170, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 153, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 160, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 170, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 172, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 178, 'Outlet 2': 159, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 172, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 164, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 156, 'Library Cafe': 185}),
#   Counter({'Outlet 1': 187, 'Outlet 2': 164, 'Library Cafe': 149})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 164, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 176, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 182, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 162, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 164, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 179, 'Outlet 2': 156, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 160, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 181, 'Library Cafe': 146})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 167, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 176, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 155, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 167, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 145, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 183, 'Library Cafe': 158})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 165, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 168, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 155, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 146, 'Outlet 2': 170, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 178, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 166, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 160, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 161, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 154, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 150, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 178, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 176, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 193, 'Outlet 2': 145, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 174, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 177, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 177, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 169, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 163, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 170, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 161, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 134, 'Outlet 2': 185, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 179, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 166, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 165, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 171, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 166, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 152, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 159, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 156, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 176, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 158, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 147, 'Outlet 2': 169, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 183, 'Library Cafe': 147})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 166, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 175, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 162, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 184, 'Outlet 2': 140, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 178, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 171, 'Library Cafe': 149})),
#  (Counter({'Outlet 1': 141, 'Outlet 2': 175, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 160, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 188, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 145, 'Outlet 2': 169, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 159, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 179, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 168, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 143, 'Outlet 2': 170, 'Library Cafe': 187}),
#   Counter({'Outlet 1': 136, 'Outlet 2': 169, 'Library Cafe': 195})),
#  (Counter({'Outlet 1': 180, 'Outlet 2': 156, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 181, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 184, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 172, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 163, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 169, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 178, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 160, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 164, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 175, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 171, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 160, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 179, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 175, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 165, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 153, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 143, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 166, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 183, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 188, 'Outlet 2': 151, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 190, 'Outlet 2': 146, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 167, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 165, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 186, 'Outlet 2': 142, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 157, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 158, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 172, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 161, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 170, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 165, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 156, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 165, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 177, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 159, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 179, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 169, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 146, 'Outlet 2': 178, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 170, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 161, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 170, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 162, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 142, 'Outlet 2': 160, 'Library Cafe': 198})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 173, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 171, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 168, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 178, 'Outlet 2': 165, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 176, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 164, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 158, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 153, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 172, 'Library Cafe': 149}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 172, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 159, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 179, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 148, 'Outlet 2': 174, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 152, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 174, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 165, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 158, 'Library Cafe': 188})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 160, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 167, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 165, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 171, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 167, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 167, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 175, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 158, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 158, 'Library Cafe': 188}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 164, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 173, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 171, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 163, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 154, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 165, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 159, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 170, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 158, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 160, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 171, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 148, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 167, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 148, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 160, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 158, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 162, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 171, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 165, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 164, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 184, 'Outlet 2': 164, 'Library Cafe': 152})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 158, 'Library Cafe': 187}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 161, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 167, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 181, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 148, 'Outlet 2': 176, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 179, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 157, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 164, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 176, 'Library Cafe': 148}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 186, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 164, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 179, 'Outlet 2': 161, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 157, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 149, 'Outlet 2': 171, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 172, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 168, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 148, 'Library Cafe': 192}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 163, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 176, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 169, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 183, 'Outlet 2': 156, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 177, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 168, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 167, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 177, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 152, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 179, 'Outlet 2': 142, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 156, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 164, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 163, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 162, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 179, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 155, 'Library Cafe': 184})),
#  (Counter({'Outlet 1': 188, 'Outlet 2': 160, 'Library Cafe': 152}),
#   Counter({'Outlet 1': 149, 'Outlet 2': 184, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 172, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 162, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 169, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 157, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 170, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 168, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 187, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 146, 'Outlet 2': 156, 'Library Cafe': 198})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 166, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 168, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 193, 'Library Cafe': 140}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 160, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 162, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 153, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 145, 'Outlet 2': 186, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 160, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 168, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 162, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 152, 'Outlet 2': 164, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 141, 'Outlet 2': 167, 'Library Cafe': 192})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 154, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 161, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 157, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 160, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 148, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 162, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 166, 'Library Cafe': 153}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 176, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 173, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 150, 'Library Cafe': 192})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 162, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 160, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 177, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 146, 'Outlet 2': 169, 'Library Cafe': 185})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 179, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 171, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 159, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 171, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 138, 'Library Cafe': 189}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 162, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 157, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 163, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 155, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 168, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 186, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 187, 'Library Cafe': 144})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 159, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 182, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 149, 'Outlet 2': 187, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 147, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 158, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 151, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 155, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 149, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 173, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 170, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 171, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 190, 'Outlet 2': 143, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 181, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 184, 'Outlet 2': 146, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 190, 'Library Cafe': 148}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 159, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 175, 'Library Cafe': 150}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 153, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 176, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 156, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 171, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 180, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 154, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 164, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 174, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 172, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 159, 'Library Cafe': 187}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 168, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 166, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 186, 'Outlet 2': 150, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 144, 'Outlet 2': 174, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 145, 'Library Cafe': 195}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 154, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 155, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 160, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 162, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 178, 'Outlet 2': 169, 'Library Cafe': 153})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 175, 'Library Cafe': 153}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 178, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 163, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 166, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 185, 'Outlet 2': 159, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 171, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 164, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 163, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 169, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 175, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 166, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 158, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 161, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 153, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 159, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 159, 'Outlet 2': 174, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 171, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 167, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 178, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 144, 'Library Cafe': 193}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 176, 'Library Cafe': 153})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 177, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 142, 'Outlet 2': 177, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 182, 'Library Cafe': 148}),
#   Counter({'Outlet 1': 154, 'Outlet 2': 170, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 170, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 155, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 163, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 179, 'Library Cafe': 152})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 156, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 160, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 174, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 165, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 180, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 166, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 166, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 136, 'Outlet 2': 186, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 168, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 148, 'Library Cafe': 191})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 152, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 166, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 179, 'Library Cafe': 155}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 164, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 167, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 170, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 156, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 170, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 158, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 168, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 148, 'Outlet 2': 167, 'Library Cafe': 185}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 187, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 155, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 177, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 156, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 176, 'Library Cafe': 151})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 164, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 155, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 177, 'Library Cafe': 152}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 172, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 169, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 154, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 158, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 167, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 165, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 161, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 171, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 163, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 151, 'Outlet 2': 171, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 158, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 167, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 166, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 166, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 159, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 180, 'Library Cafe': 147}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 142, 'Library Cafe': 177})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 148, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 159, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 168, 'Library Cafe': 171}),
# ...
#   Counter({'Outlet 1': 169, 'Outlet 2': 148, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 164, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 160, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 176, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 177, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 161, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 155, 'Outlet 2': 173, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 160, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 163, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 160, 'Library Cafe': 163})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 168, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 188, 'Outlet 2': 162, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 169, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 164, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 168, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 158, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 156, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 189, 'Library Cafe': 148})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 152, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 176, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 169, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 166, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 152, 'Library Cafe': 171}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 172, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 155, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 183, 'Library Cafe': 164})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 151, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 168, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 148, 'Library Cafe': 187}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 173, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 163, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 160, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 150, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 161, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 180, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 159, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 145, 'Outlet 2': 166, 'Library Cafe': 189}),
#   Counter({'Outlet 1': 145, 'Outlet 2': 155, 'Library Cafe': 200})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 175, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 158, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 155, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 178, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 156, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 158, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 147, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 168, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 188, 'Outlet 2': 156, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 148, 'Outlet 2': 167, 'Library Cafe': 185})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 166, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 155, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 148, 'Library Cafe': 191}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 157, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 178, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 171, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 140, 'Outlet 2': 180, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 184, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 185, 'Library Cafe': 141}),
#   Counter({'Outlet 1': 145, 'Outlet 2': 162, 'Library Cafe': 193})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 167, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 184, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 151, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 176, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 172, 'Outlet 2': 171, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 138, 'Library Cafe': 185})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 169, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 187, 'Outlet 2': 158, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 171, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 171, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 174, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 162, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 155, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 165, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 166, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 159, 'Outlet 2': 152, 'Library Cafe': 189})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 171, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 173, 'Library Cafe': 157})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 167, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 167, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 184, 'Outlet 2': 150, 'Library Cafe': 166}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 166, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 165, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 151, 'Outlet 2': 176, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 152, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 169, 'Outlet 2': 165, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 165, 'Outlet 2': 173, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 167, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 187, 'Outlet 2': 153, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 168, 'Outlet 2': 157, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 153, 'Outlet 2': 174, 'Library Cafe': 173}),
#   Counter({'Outlet 1': 181, 'Outlet 2': 151, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 174, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 187, 'Outlet 2': 141, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 154, 'Outlet 2': 165, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 170, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 179, 'Outlet 2': 159, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 182, 'Outlet 2': 173, 'Library Cafe': 145}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 173, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 158, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 142, 'Outlet 2': 182, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 160, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 165, 'Library Cafe': 159})),
#  (Counter({'Outlet 1': 187, 'Outlet 2': 151, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 163, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 150, 'Outlet 2': 171, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 173, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 148, 'Library Cafe': 183}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 165, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 146, 'Outlet 2': 166, 'Library Cafe': 188}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 177, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 165, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 180, 'Outlet 2': 167, 'Library Cafe': 153})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 170, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 172, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 176, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 154, 'Library Cafe': 188})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 163, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 178, 'Library Cafe': 162})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 154, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 176, 'Library Cafe': 166})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 178, 'Library Cafe': 154}),
#   Counter({'Outlet 1': 186, 'Outlet 2': 164, 'Library Cafe': 150})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 168, 'Library Cafe': 159}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 170, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 151, 'Outlet 2': 171, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 175, 'Outlet 2': 151, 'Library Cafe': 174})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 175, 'Library Cafe': 157}),
#   Counter({'Outlet 1': 144, 'Outlet 2': 191, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 170, 'Outlet 2': 170, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 176, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 159, 'Library Cafe': 172}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 170, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 174, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 138, 'Outlet 2': 187, 'Library Cafe': 175})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 165, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 165, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 155, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 170, 'Outlet 2': 184, 'Library Cafe': 146})),
#  (Counter({'Outlet 1': 160, 'Outlet 2': 163, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 182, 'Outlet 2': 163, 'Library Cafe': 155})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 148, 'Library Cafe': 184}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 158, 'Library Cafe': 171})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 156, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 166, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 159, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 168, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 165, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 184, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 175, 'Outlet 2': 156, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 160, 'Library Cafe': 176})),
#  (Counter({'Outlet 1': 156, 'Outlet 2': 162, 'Library Cafe': 182}),
#   Counter({'Outlet 1': 157, 'Outlet 2': 163, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 168, 'Outlet 2': 171, 'Library Cafe': 161}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 167, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 170, 'Library Cafe': 153}),
#   Counter({'Outlet 1': 156, 'Outlet 2': 175, 'Library Cafe': 169})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 175, 'Library Cafe': 151}),
#   Counter({'Outlet 1': 147, 'Outlet 2': 166, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 181, 'Outlet 2': 161, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 173, 'Outlet 2': 141, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 183, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 156, 'Library Cafe': 182})),
#  (Counter({'Outlet 1': 176, 'Outlet 2': 164, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 191, 'Outlet 2': 161, 'Library Cafe': 148})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 150, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 171, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 141, 'Outlet 2': 184, 'Library Cafe': 175}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 167, 'Library Cafe': 167})),
#  (Counter({'Outlet 1': 157, 'Outlet 2': 158, 'Library Cafe': 185}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 167, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 167, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 164, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 157, 'Library Cafe': 180}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 154, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 182, 'Outlet 2': 149, 'Library Cafe': 169}),
#   Counter({'Outlet 1': 164, 'Outlet 2': 157, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 160, 'Library Cafe': 177}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 156, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 179, 'Outlet 2': 153, 'Library Cafe': 168}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 150, 'Library Cafe': 183})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 160, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 164, 'Library Cafe': 170})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 151, 'Library Cafe': 176}),
#   Counter({'Outlet 1': 166, 'Outlet 2': 180, 'Library Cafe': 154})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 173, 'Library Cafe': 165}),
#   Counter({'Outlet 1': 183, 'Outlet 2': 157, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 153, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 161, 'Outlet 2': 159, 'Library Cafe': 180})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 145, 'Library Cafe': 178}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 177, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 169, 'Outlet 2': 169, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 176, 'Outlet 2': 156, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 152, 'Library Cafe': 170}),
#   Counter({'Outlet 1': 153, 'Outlet 2': 158, 'Library Cafe': 189})),
#  (Counter({'Outlet 1': 163, 'Outlet 2': 175, 'Library Cafe': 162}),
#   Counter({'Outlet 1': 171, 'Outlet 2': 181, 'Library Cafe': 148})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 175, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 182, 'Outlet 2': 165, 'Library Cafe': 153})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 153, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 182, 'Outlet 2': 146, 'Library Cafe': 172})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 159, 'Library Cafe': 174}),
#   Counter({'Outlet 1': 162, 'Outlet 2': 157, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 163, 'Library Cafe': 160}),
#   Counter({'Outlet 1': 143, 'Outlet 2': 192, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 177, 'Outlet 2': 167, 'Library Cafe': 156}),
#   Counter({'Outlet 1': 150, 'Outlet 2': 169, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 171, 'Outlet 2': 180, 'Library Cafe': 149}),
#   Counter({'Outlet 1': 163, 'Outlet 2': 164, 'Library Cafe': 173})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 163, 'Library Cafe': 163}),
#   Counter({'Outlet 1': 167, 'Outlet 2': 168, 'Library Cafe': 165})),
#  (Counter({'Outlet 1': 173, 'Outlet 2': 169, 'Library Cafe': 158}),
#   Counter({'Outlet 1': 152, 'Outlet 2': 167, 'Library Cafe': 181})),
#  (Counter({'Outlet 1': 161, 'Outlet 2': 150, 'Library Cafe': 189}),
#   Counter({'Outlet 1': 172, 'Outlet 2': 167, 'Library Cafe': 161})),
#  (Counter({'Outlet 1': 178, 'Outlet 2': 172, 'Library Cafe': 150}),
#   Counter({'Outlet 1': 177, 'Outlet 2': 163, 'Library Cafe': 160})),
#  (Counter({'Outlet 1': 167, 'Outlet 2': 166, 'Library Cafe': 167}),
#   Counter({'Outlet 1': 174, 'Outlet 2': 158, 'Library Cafe': 168})),
#  (Counter({'Outlet 1': 148, 'Outlet 2': 159, 'Library Cafe': 193}),
#   Counter({'Outlet 1': 178, 'Outlet 2': 166, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 162, 'Outlet 2': 150, 'Library Cafe': 188}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 163, 'Library Cafe': 179})),
#  (Counter({'Outlet 1': 174, 'Outlet 2': 147, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 155, 'Outlet 2': 159, 'Library Cafe': 186})),
#  (Counter({'Outlet 1': 164, 'Outlet 2': 172, 'Library Cafe': 164}),
#   Counter({'Outlet 1': 158, 'Outlet 2': 155, 'Library Cafe': 187})),
#  (Counter({'Outlet 1': 147, 'Outlet 2': 167, 'Library Cafe': 186}),
#   Counter({'Outlet 1': 186, 'Outlet 2': 158, 'Library Cafe': 156})),
#  (Counter({'Outlet 1': 158, 'Outlet 2': 163, 'Library Cafe': 179}),
#   Counter({'Outlet 1': 160, 'Outlet 2': 162, 'Library Cafe': 178})),
#  (Counter({'Outlet 1': 166, 'Outlet 2': 153, 'Library Cafe': 181}),
#   Counter({'Outlet 1': 165, 'Outlet 2': 147, 'Library Cafe': 188})),
#  ...]
